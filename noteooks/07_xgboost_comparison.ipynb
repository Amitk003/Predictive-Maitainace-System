# %%
import sklearn
import scipy
import numpy

print("Python:", sys.version)
print("Scikit-learn:", sklearn.__version__)
print("SciPy:", scipy.__version__)
print("NumPy:", numpy.__version__)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import sklearn
#       2 import scipy
#       3 import numpy
#       4
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "callback",
#    (...)    112     "compose",
#     113 ]
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:21
#      19 from sklearn.exceptions import InconsistentVersionWarning
#      20 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 21 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      22 from sklearn.utils._param_validation import validate_parameter_constraints
#      23 from sklearn.utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:17
#      14 from scipy.sparse import csr_array, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _is_numpy_namespace,
#      27     _max_precision_float_dtype,
#      28     get_namespace,
#      29     get_namespace_and_device,
#      30     move_to,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_array_api.py:23
#      21 from sklearn.externals.array_api_compat import numpy as np_compat
#      22 from sklearn.utils._dataframe import is_df_or_series
# ---> 23 from sklearn.utils.fixes import parse_version
#      25 # TODO: complete __all__
#      26 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\fixes.py:16
#      14 import scipy
#      15 import scipy.sparse.linalg
# ---> 16 import scipy.stats
#      18 try:
#      19     import pandas as pd
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\__init__.py:600
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    595
#     596 """  # noqa: E501
#     598 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     599                                DegenerateDataWarning, FitError)
# --> 600 from ._stats_py import *
#     601 from ._variation import variation
#     602 from .distributions import *
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_stats_py.py:50
#      46 import scipy.special as special
#      47 # Import unused here but needs to stay until end of deprecation periode
#      48 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      49 from scipy import linalg  # noqa: F401
# ---> 50 from . import distributions
#      51 from . import _mstats_basic as mstats_basic
#      52
#      53 from ._stats import _kendall_dis, _toint64, _weightedrankedtau
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)      6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_continuous_distns.py:13
#       9 import operator
#      10
#      11 import numpy as np
#      12 from numpy.polynomial import Polynomial
# ---> 13 from scipy.interpolate import BSpline
#      14 from scipy._lib.doccer import (extend_notes_in_docstring,
#      15                                replace_notes_in_docstring,
#      16                                inherit_docstring_from)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\interpolate\__init__.py:199
#     195 from ._fitpack2 import *
#     197 from ._rbf import Rbf
# --> 199 from ._rbfinterp import *
#     201 from ._polyint import *
#     203 from ._cubic import *
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\interpolate\_rbfinterp.py:8
#       5 import numpy as np
#       6 from scipy.spatial import KDTree
# ----> 8 from . import _rbfinterp_np
#       9 from . import _rbfinterp_xp
#      11 from scipy._lib._array_api import (
#      12     _asarray, array_namespace, xp_size, is_numpy, xp_capabilities
#      13 )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\interpolate\_rbfinterp_np.py:6
#       3 from scipy.linalg.lapack import get_lapack_funcs
#       4 from ._rbfinterp_common import _monomial_powers_impl
# ----> 6 from ._rbfinterp_pythran import (
#       7     _build_system as _pythran_build_system,
#       8     _build_evaluation_coefficients as _pythran_build_evaluation_coefficients,
#       9     _polynomial_matrix as _pythran_polynomial_matrix
#      10 )
#      13 dsysv = get_lapack_funcs('sysv', dtype=np.float64, ilp64="preferred")
#      16 # trampolines for pythran-compiled functions to drop the `xp` argument
#
# ImportError: DLL load failed while importing _rbfinterp_pythran: An Application Control policy has blocked this file.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\python.exe
